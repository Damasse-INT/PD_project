# %%
# %load_ext autoreload
# %autoreload 2
% matplotlib inline
import warnings
import PD_module 
import numpy as np
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")

# %%
datas, jals, participants = PD_module.FOI_builder()

traces = PD_module.traces_cleaner(datas, participants, jals, time_span=np.arange(0, 1400), types='velocity',
                    tolerance_crit=[65, 65, 65], Out_crit=1)

# %% [raw]
# for c in ['ctl', 'exp']:
#     PD_module.traces_plotter(traces, participants, c,
#                              conditions=['Healthy', 'On', 'Off'], close_policy=False)

# %% [markdown]
# #### To do list
# 1 - back to matlab to extract Y velocity
#
# 2 - do following analysis Vy = f(Vx) ou Vy = f(t)
#
# 3 - Don't hesitate to lose data to smooth the signal a lot

# %%
PD_module.vec_latency_VX_vs_T(traces, participants, journal=jals, crit=0.01, 
                      conditions=['Healthy', 'On', 'Off'], close_policy=False)
